# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
# %cd E:\ALL0001
# Out:
# E:\ALL0001

# %%
d1=np.genfromtxt('F0001CH1.CSV', delimiter=',')
d2=np.genfromtxt('F0001CH2.CSV', delimiter=',')
d3=np.genfromtxt('F0001CH3.CSV', delimiter=',')

# %%
t=d1[:,0]
I1=d1[:,1]
I2=d2[:,1]
I3=d3[:,1]

# %%
plt.plot(t,I1)
plt.plot(t,I2)
plt.plot(t,I3)
# Out:
# <img src="data:image/png;base64,...">

# %%
I_Tot=I1**2+I2**2+I3**2
I1n=I1/I_Tot
I2n=I2/I_Tot
I3n=I3/I_Tot

# %%
fig,ax=plt.subplots()
ax.plot(t,I1n)
ax.plot(t,I2n)
ax.plot(t,I3n)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %cd "E:\ALL0003"
fn='F0003'
t=np.genfromtxt(fn+'CH1.CSV', delimiter=',')[:,0]
I1=np.genfromtxt(fn+'CH1.CSV', delimiter=',')[:,1]
I2=np.genfromtxt(fn+'CH2.CSV', delimiter=',')[:,1]
I3=np.genfromtxt(fn+'CH3.CSV', delimiter=',')[:,1]
# Out:
# E:\ALL0003

# %%
fig,ax=plt.subplots()
ax.scatter(I2,I1, alpha='0.05')
ax.scatter(I3,I1, c='r', alpha='0.05')
# Out:
# <img src="data:image/png;base64,...">

# %%
from numpy.linalg import eig, inv

def fitEllipse(x,y):
    x = x[:,np.newaxis]
    y = y[:,np.newaxis]
    D =  np.hstack((x*x, x*y, y*y, x, y, np.ones_like(x)))
    S = np.dot(D.T,D)
    C = np.zeros([6,6])
    C[0,2] = C[2,0] = 2; C[1,1] = -1
    E, V =  eig(np.dot(inv(S), C))
    n = np.argmax(np.abs(E))
    a = V[:,n]
    return a

def ellipse_center(a):
    b,c,d,f,g,a = a[1]/2, a[2], a[3]/2, a[4]/2, a[5], a[0]
    num = b*b-a*c
    x0=(c*d-b*f)/num
    y0=(a*f-b*d)/num
    return np.array([x0,y0])


def ellipse_angle_of_rotation( a ):
    b,c,d,f,g,a = a[1]/2, a[2], a[3]/2, a[4]/2, a[5], a[0]
    return 0.5*np.arctan(2*b/(a-c))

def ellipse_angle_of_rotation2( a ):
    b,c,d,f,g,a = a[1]/2, a[2], a[3]/2, a[4]/2, a[5], a[0]
    if b == 0:
        if a > c:
            return 0
        else:
            return np.pi/2
    else:
        if a > c:
            return np.arctan(2*b/(a-c))/2
        else:
            return np.pi/2 + np.arctan(2*b/(a-c))/2


def ellipse_axis_length( a ):
    b,c,d,f,g,a = a[1]/2, a[2], a[3]/2, a[4]/2, a[5], a[0]
    up = 2*(a*f*f+c*d*d+g*b*b-2*b*d*f-a*c*g)
    down1=(b*b-a*c)*( (c-a)*np.sqrt(1+4*b*b/((a-c)*(a-c)))-(c+a))
    down2=(b*b-a*c)*( (a-c)*np.sqrt(1+4*b*b/((a-c)*(a-c)))-(c+a))
    res1=np.sqrt(up/down1)
    res2=np.sqrt(up/down2)
    return np.array([res1, res2])

# %%
fE = fitEllipse(I3,I1)
center = ellipse_center(fE)
#phi = ellipse_angle_of_rotation(a)
phi = ellipse_angle_of_rotation2(fE)
axes = ellipse_axis_length(fE)
R=np.linspace(0,2*np.pi,1000)


a, b = axes
xx = center[0] + a*np.cos(R)*np.cos(phi) - b*np.sin(R)*np.sin(phi)
yy = center[1] + a*np.cos(R)*np.sin(phi) + b*np.sin(R)*np.cos(phi)

fig,ax=plt.subplots()
ax.scatter(I3,I1, alpha='0.05')
ax.plot(xx,yy)
# Out:
# <img src="data:image/png;base64,...">

# %%
a,b,c,d,e,f=fE

discrim=b**2-4*a*c
if discrim>=0:
    print('This is NOT an ellipse')

epsilon=np.arcsin(b/np.sqrt(4*a*c));

x0=-(e*b-2*c*d)/discrim;
y0=-(b*d-2*a*e)/discrim;

Ax=1/np.cos(epsilon)*np.sqrt(x0**2+(b/a)*x0*y0+(c/a)*y0**2-(f/a))
Ay=1/np.cos(epsilon)*np.sqrt((a/c)*x0**2+(b/c)*x0*y0+y0**2-(f/c))
print (x0,y0,Ax,Ay,epsilon+np.pi/2)
# Out:
# 0.0344145040719 0.0430825598134 0.0104025483475 0.00922225188005 1.23639950826

# %%
R=np.linspace(0,2*np.pi,100)
A1=1
B1=1
D1=B1+A1*np.cos(R)

A2=2
B2=1
Beta2=np.pi/3
D2=B2+A2*np.cos(R-Beta2)

fE=fitEllipse(D2,D1)

center = ellipse_center(fE)
#phi = ellipse_angle_of_rotation(a)
phi = ellipse_angle_of_rotation2(fE)
a,b = ellipse_axis_length(fE)

phi=phi
xx = center[0] + a*np.cos(Rp)*np.cos(phi) - b*np.sin(Rp)*np.sin(phi)
yy = center[1] + a*np.cos(Rp)*np.sin(phi) + b*np.sin(Rp)*np.cos(phi)

fig,ax=plt.subplots()
ax.scatter(D2,D1)
plt.axis('equal')

ax.plot(xx,yy)
# Out:
# <img src="data:image/png;base64,...">

# %%
a,b,c,d,e,f=fE

discrim=b**2-4*a*c
if discrim>=0:
    print('This is NOT an ellipse')

epsilon=np.arcsin(b/np.sqrt(4*a*c));

x0=-(e*b-2*c*d)/discrim;
y0=-(b*d-2*a*e)/discrim;

Ax=1/np.cos(epsilon)*np.sqrt(x0**2+(b/a)*x0*y0+(c/a)*y0**2-(f/a))
Ay=1/np.cos(epsilon)*np.sqrt((a/c)*x0**2+(b/c)*x0*y0+y0**2-(f/c))
print(B1, B2, A1, A2, Beta2)
print (x0,y0,Ax,Ay,epsilon+np.pi/2)
# Out:
# 1 1 1 2 1.0471975511965976
# 1.0 1.0 2.0 1.0 1.0471975512

# %%
# Out:
# 1.0 1.0 2.0 1.0 -0.523598775598

# %%
a,b,c,d,e,f=fE

# %%
b
# Out:
# (-0.52981294282601876+0j)
