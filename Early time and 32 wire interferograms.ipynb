# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import colormaps as cmaps
import matplotlib.gridspec as gridspec
from magpie_data import NeLMap2
# Out:
# c:\users\jdavies\anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %% [markdown]
# ## s0119_16: 16 wire, gap vs gap. t=168 ns (Chico misfired)

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0119_16 C RECONNECTION 12 FRAME"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0119_16 C RECONNECTION 12 FRAME

# %%
s0119_16_532=NeLMap2('s0119_16 532nm neL.txt', scale=173, rot_angle=-90-20)
s=s0119_16_532
title='s0119_16, t=171ns'
s.data=s.data-3e17

# %%
s.set_origin(origin=[2906,2182], extent=[-11.5,11.5,-8,8])

fig, ax=plt.subplots(figsize=(8,8))
im=s.plot_data_mm(clim=[0,10], multiply_by=1/1.6e17, ax=ax)
ax.set_title(title, fontsize=28)

ax.set_xlabel('x (mm)',fontsize=28)
ax.set_ylabel('y (mm)',fontsize=28)
ax.set_xticks([-5,0,5])

ax.tick_params(labelsize=28, pad=5, length=10, width=2)


cbar_ax = fig.add_axes([0.80, 0.10, 0.05, 0.8])#l,b,w,h
cbar_ax.tick_params(labelsize=28, pad=5, length=10, width=2)
fig.colorbar(im, cax=cbar_ax, ticks=[0,2,4,6,8,10])
cbar_ax.set_ylabel(r'$n_e$ ($\times$ 10$^{17}$ cm$^{-3}$)',fontsize=28)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## s0120_16: 16 wire, gap vs gap. t=171 ns (Dodgy wire?)

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0120_16 C RECONNECTION 12 FRAME"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0120_16 C RECONNECTION 12 FRAME

# %%
s0120_16_532=NeLMap2('s0120_16 532nm neL.txt', scale=173, rot_angle=-90-20)
s=s0120_16_532
title='s0120_16, t=171ns'

# %%
s.set_origin(origin=[2749,2053], extent=[-11.5,11.5,-8,8])

fig, ax=plt.subplots(figsize=(8,8))
im=s.plot_data_mm(clim=[0,10], multiply_by=1/1.6e17, ax=ax)
ax.set_title(title, fontsize=28)

ax.set_xlabel('x (mm)',fontsize=28)
ax.set_ylabel('y (mm)',fontsize=28)
ax.set_xticks([-5,0,5])

ax.tick_params(labelsize=28, pad=5, length=10, width=2)


cbar_ax = fig.add_axes([0.80, 0.10, 0.05, 0.8])#l,b,w,h
cbar_ax.tick_params(labelsize=28, pad=5, length=10, width=2)
fig.colorbar(im, cax=cbar_ax, ticks=[0,2,4,6,8,10])
cbar_ax.set_ylabel(r'$n_e$ ($\times$ 10$^{17}$ cm$^{-3}$)',fontsize=28)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## s0122_16: 16 wire, wire vs wire. t=178 ns

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0122_16 C RECONNECTION 12 FRAME"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0122_16 C RECONNECTION 12 FRAME

# %%
s0122_16_532=NeLMap2('s0122_16 532nm neL.txt', scale=173, rot_angle=-90-20)
s=s0122_16_532
title='s0122_16, t=178ns'

# %%
s.set_origin(origin=[2683,2156], extent=[-11.5,11.5,-8,8])

fig, ax=plt.subplots(figsize=(8,8))
im=s.plot_data_mm(clim=[0,10], multiply_by=1/1.6e17, ax=ax)
ax.set_title(title, fontsize=28)

ax.set_xlabel('x (mm)',fontsize=28)
ax.set_ylabel('y (mm)',fontsize=28)
ax.set_xticks([-5,0,5])

ax.tick_params(labelsize=28, pad=5, length=10, width=2)


cbar_ax = fig.add_axes([0.80, 0.10, 0.05, 0.8])#l,b,w,h
cbar_ax.tick_params(labelsize=28, pad=5, length=10, width=2)
fig.colorbar(im, cax=cbar_ax, ticks=[0,2,4,6,8,10])
cbar_ax.set_ylabel(r'$n_e$ ($\times$ 10$^{17}$ cm$^{-3}$)',fontsize=28)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## s0125_16: 32 wire, wire vs wire. t=246 ns

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0125_16 C RECONNECTION 12 FRAME"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0125_16 C RECONNECTION 12 FRAME

# %%
s0125_16_532=NeLMap2('s0125_16 532nm neL.txt', scale=173, rot_angle=-90-21.5)
s=s0125_16_532
title='s0125_16, t=248ns'

# %%
s.set_origin(origin=[2724,2197], extent=[-11.5,11.5,-8,8])

fig, ax=plt.subplots(figsize=(8,8))
im=s.plot_data_mm(clim=[0,10], multiply_by=1/1.6e17, ax=ax)
ax.set_title(title, fontsize=28)

ax.set_xlabel('x (mm)',fontsize=28)
ax.set_ylabel('y (mm)',fontsize=28)
ax.set_xticks([-5,0,5])

ax.tick_params(labelsize=28, pad=5, length=10, width=2)


cbar_ax = fig.add_axes([0.80, 0.10, 0.05, 0.8])#l,b,w,h
cbar_ax.tick_params(labelsize=28, pad=5, length=10, width=2)
fig.colorbar(im, cax=cbar_ax, ticks=[0,2,4,6,8,10])
cbar_ax.set_ylabel(r'$n_e$ ($\times$ 10$^{17}$ cm$^{-3}$)',fontsize=28)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## s1029_15:  32 wire, wire vs wire. t=329 ns

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2015\s1029_15 Reconnection C 32 Wire TS in layer 280 ns
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2015\s1029_15 Reconnection C 32 Wire TS in layer 280 ns

# %%
s1029_15_532=NeLMap2('s1029_15 532nm neL.txt', scale=173, rot_angle=-90)
s=s1029_15_532
title='s1029_15, t=348ns'

# %%
s.set_origin(origin=[2491,1406], extent=[-11.5,11.5,-8,8])

fig, ax=plt.subplots(figsize=(8,8))
im=s.plot_data_mm(clim=[0,10], multiply_by=1/1.6e17, ax=ax)
ax.set_title(title, fontsize=28)

ax.set_xlabel('x (mm)',fontsize=28)
ax.set_ylabel('y (mm)',fontsize=28)
ax.set_xticks([-5,0,5])

ax.tick_params(labelsize=28, pad=5, length=10, width=2)


cbar_ax = fig.add_axes([0.80, 0.10, 0.05, 0.8])#l,b,w,h
cbar_ax.tick_params(labelsize=28, pad=5, length=10, width=2)
fig.colorbar(im, cax=cbar_ax, ticks=[0,2,4,6,8,10])
cbar_ax.set_ylabel(r'$n_e$ ($\times$ 10$^{17}$ cm$^{-3}$)',fontsize=28)
# Out:
# <img src="data:image/png;base64,...">

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0119_16 C RECONNECTION 12 FRAME"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0119_16 C RECONNECTION 12 FRAME

# %%
fn='s0119_16 532nm neL.txt'
d=np.loadtxt(open(fn,"r"),delimiter=",")

# %%
dd=d-np.nan_to_num(d).min()

# %%
np.nan_to_num(dd).min()
# Out:
# 0.0
