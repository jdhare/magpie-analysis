# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
cd '~/Downloads'
# Out:
# C:\Users\jdavies\Downloads

# %%
Bcol=np.loadtxt(open('by_08_reconneciton.csv',"r"),delimiter=",", skiprows=1)

# %%
necol=np.loadtxt(open('rnec_08_reconneciton.csv',"r"),delimiter=",", skiprows=1)

# %%
BYcol=Bcol[:,1]

# %%
necol=necol[:,0]

# %%
BY=BYcol.reshape((1121,559), order='C')
plt.imshow(BY)

# %%
ne=necol.reshape((560,1120), order='A')
plt.imshow(ne)

# %%
560*1120, BYcol.shape
# Out:
# (627200, (627200,))
