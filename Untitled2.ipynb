# %%
# %matplotlib inline

# %%
from bdots import *

# %%
r=Rogowskis("s1026_15")
r.truncate(cal=[10*10.4*3e9,10.48*10.79*3e9])
r.integrate()
r.plot("I", scale=1e-6)
# Out:
# s1026_15: using Rog 1 only

# %%
r.plot("I", scale=1)

# %%
r.I2.max()<5e5
# Out:
# True
