# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0905_16 Reconnection C TS+Far"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0905_16 Reconnection C TS+Far

# %%
data=np.loadtxt('s0905_16 XRDs 234.csv', skiprows=15, delimiter=',')

# %%
t=data[:,0]
Be=data[:,2]
Al=data[:,3]
PCB=data[:,4]

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(t*1e9,Be)
ax.plot(t*1e9,PCB)
ax.plot(t*1e9,Al)


ax.set_xlim([0,10000])
# Out:
# <img src="data:image/png;base64,...">
# (0, 10000)
