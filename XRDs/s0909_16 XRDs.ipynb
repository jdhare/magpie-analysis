# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
cd "\\linna\Users\Magpie\Documents\MAGPIE data\2016\Sept_2016\s0909_16 Reconnection Al - Faraday + TS horizontal"
# Out:
# \\linna\Users\Magpie\Documents\MAGPIE data\2016\Sept_2016\s0909_16 Reconnection Al - Faraday + TS horizontal

# %%
data=np.loadtxt('s0909_16 XRDs 234.csv', skiprows=15, delimiter=',')

# %%
t=data[:,0]
Be=data[:,2]
Al=data[:,3]
PCB=data[:,4]

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(t*1e9,Be)
ax.plot(t*1e9,PCB)
ax.plot(t*1e9,Al)


ax.set_xlim([1500,2000])
# Out:
# <img src="data:image/png;base64,...">
# (1500, 2000)
