# %% [markdown]
# # Fitting Thomson Scattering Spectrum

# %% [markdown]
# See Spectra_fitting_README.md for details

# %%
# %matplotlib inline
import ts_analysis as TsA
import os

# %% [markdown]
# # s1123_16

# %%
folder=r"\\LINNA\Users\Magpie\Documents\MAGPIE data\2016\Nov_2016\s1122_16\s1123_16 TS"
shot_fn='s1123_16 shot.asc'
ts=TsA.TS_Analysis(folder, shot_fn,['s1121_16 full power bk.asc'])

ts.find_fibre_edges()

# %%
'''Split image into fibres'''
ts.split_into_fibres(discard_rows=3)
ts.zero_fibres(upper=1150, lower=850)
a_angle=[90]*14 #here we have fibres 1A through 14A at an angle of 45'
b_angle=[270]*14
ts.pair_fibres(a_angle,b_angle)

# %%
'''
Specify the plasma parameters in the form (V
alues, Minimum, Independent)
If Independent is True, then the value is fixed and minimum has no meaning
If Independent is False, then the value is an initial guess for the fit
and minimum is either a float, or None to specify no given minimum
For multi-species fits, Aj, Zj and Fj only can have their value as a tuple (A1,A2...Aj)
Even for a single-species fit, enclose A, Z and F in (), eg. 'Aj':((12), True, None)
'''
'''Choose the fibre to fit'''
Fnum=1
Fset='A'


plasma_parameters={ 'model': 'nLTE',
                    'n_e': (1e18,True),#in cm^-3, must be specified
                    'T_e': (100, False,1),#In electron volts. 
                    'V_fe':(0, True),#m/s.
                    'A':  ((138,), True),#in nucleon masses, must be specified
                    'T_i': (1000, False),#In electron volts.
                    'V_fi':(0, False),#m/s.
                    'stry':(100, False,0), #Fraction of signal made up of stray light. >0, <1.0!!
                    'amp': (3000, False,0), #Fraction of signal made up of spectrum.
                    'offset': (120, False), #
                    'shift': (0, True)
                    }

'''This code fits and plots the result'''
f=ts.select_fibre(Fnum,Fset)
f.voigt_response()
f.fit_fibre(plasma_parameters)
ts.pretty_plot(Fnum,Fset, tm=1.6, sr=12)
print(f.skw_res.fit_report())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ae7d9cf5c9f9> in <module>()
#      29 f=ts.select_fibre(Fnum,Fset)
#      30 f.voigt_response()
# ---> 31 f.fit_fibre(plasma_parameters)
#      32 ts.pretty_plot(Fnum,Fset, tm=1.6, sr=12)
#      33 print(f.skw_res.fit_report())
#
# C:\Users\jdhare\Documents\GitHub\thomson_scattering\ts_analysis.py in fit_fibre(self, pp)
#     118
#     119         '''now do the fitting'''
# --> 120         skw_res=skw.fit(self.shot,verbose=False, **iv_dict)
#     121         self.skw_res=skw_res
#     122         ##Calculating alpha. This is really ugly
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, **kwargs)
#     539                              scale_covar=scale_covar, fcn_kws=kwargs,
#     540                              **fit_kws)
# --> 541         output.fit(data=data, weights=weights)
#     542         output.components = self.components
#     543         return output
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, **kwargs)
#     745         self.init_fit    = self.model.eval(params=self.params, **self.userkws)
#     746
# --> 747         _ret = self.minimize(method=self.method)
#     748
#     749         for attr in dir(_ret):
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    1240                     val.lower().startswith(user_method)):
#    1241                     kwargs['method'] = val
# -> 1242         return function(**kwargs)
#    1243
#    1244
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1070         np.seterr(all='ignore')
#    1071
# -> 1072         lsout = scipy_leastsq(self.__residual, vars, **lskws)
#    1073         _best, _cov, infodict, errmsg, ier = lsout
#    1074         result.aborted = self._abort
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     385             maxfev = 200*(n + 1)
#     386         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 387                                  gtol, maxfev, epsfcn, factor, diag)
#     388     else:
#     389         if col_deriv:
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     369
#     370         out = self.userfcn(params, *self.userargs, **self.userkws)
# --> 371         out = _nan_policy(out, nan_policy=self.nan_policy)
#     372
#     373         if callable(self.iter_cb):
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\minimizer.py in _nan_policy(a, nan_policy, handle_inf)
#    1430
#    1431         if contains_nan:
# -> 1432             raise ValueError("The input contains nan values")
#    1433         return a
#    1434
#
# ValueError: The input contains nan values

# %%
ts.fig.savefig('Figures/s0611_15 fibre 8A largetext.pdf')

# %%
for i in range(1,15):
    ts.plot_data(Fnum=i, Fset='A')

# %%
for i in range(1,15):
    ts.plot_data(Fnum=i, Fset='B')
