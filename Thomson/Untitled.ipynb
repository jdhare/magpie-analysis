# %%
import csv
import numpy as np

# %%
d=np.genfromtxt('zb_W.dat', skip_header=2, usecols=[0,2])

# %%
te=d[:,0]
z=d[:,2]

# %%
# %cd "C:\Users\jdhare\Google Drive\MAGPIE\data\SPK data\W"
nLTE=np.genfromtxt('NLTE_1e18.txt', skip_header=2, usecols=[0,2])
LTE=np.genfromtxt('LTE_1e18.txt', skip_header=2, usecols=[0,2])
# Out:
# C:\Users\jdhare\Google Drive\MAGPIE\data\SPK data\W

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
plt.plot(nLTE[:,0], nLTE[:,1], label='nLTE')
plt.plot(LTE[:,0], LTE[:,1], label='LTE')
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
nLTE
