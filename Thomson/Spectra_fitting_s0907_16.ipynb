# %% [markdown]
# # Fitting Thomson Scattering Spectrum

# %% [markdown]
# See Spectra_fitting_README.md for details

# %%
# %matplotlib inline
import ts_analysis as TsA
import os

# %% [markdown]
# # s0907_16

# %%
folder=r"\\LINNA\Users\Magpie\Documents\MAGPIE data\2016\Sept_2016\s0907_15 Reconnection Al - Faraday + TS horizontal\s0907_16 TS @ 295ns"
shot_fn='s0907_16 shot.asc'
ts=TsA.TS_Analysis(folder, shot_fn,['s0907_16 full power test @ gain 100.asc'])

ts.find_fibre_edges()

# %%
'''Split image into fibres'''
ts.split_into_fibres(discard_rows=3)
ts.zero_fibres(upper=1150, lower=850)
a_angle=[45]*14 #here we have fibres 1A through 14A at an angle of 45'
b_angle=[135]*14
ts.pair_fibres(a_angle,b_angle)

# %%
'''
Specify the plasma parameters in the form (V
alues, Minimum, Independent)
If Independent is True, then the value is fixed and minimum has no meaning
If Independent is False, then the value is an initial guess for the fit
and minimum is either a float, or None to specify no given minimum
For multi-species fits, Aj, Zj and Fj only can have their value as a tuple (A1,A2...Aj)
Even for a single-species fit, enclose A, Z and F in (), eg. 'Aj':((12), True, None)
'''
'''Choose the fibre to fit'''
Fnum=6
Fset='A'


plasma_parameters={ 'model': 'nLTE',
                    'n_e': (2.8e18,True),#in cm^-3, must be specified
                    'T_e': (25, True,0),#In electron volts. 
                    'V_fe':(0, True),#m/s.
                    'A':  ((27,), True),#in nucleon masses, must be specified
                    'T_i': (30, True,0),#In electron volts.
                    'V_fi':(0, False),#m/s.
                    'stry':(0, True), #Fraction of signal made up of stray light. >0, <1.0!!
                    'amp': (9000, False), #Fraction of signal made up of spectrum.
                    'offset': (0, False), #
                    'shift': (0, True)
                    }

'''This code fits and plots the result'''
f=ts.select_fibre(Fnum,Fset)
f.voigt_response()
f.fit_fibre(plasma_parameters)
ts.pretty_plot(Fnum,Fset, tm=1.6, sr=12)
print(f.skw_res.fit_report())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-988ec21adb27> in <module>()
#      29 f=ts.select_fibre(Fnum,Fset)
#      30 f.voigt_response()
# ---> 31 f.fit_fibre(plasma_parameters)
#      32 ts.pretty_plot(Fnum,Fset, tm=1.6, sr=12)
#      33 print(f.skw_res.fit_report())
#
# C:\Users\jdhare\Documents\GitHub\thomson_scattering\ts_analysis.py in fit_fibre(self, pp)
#     118
#     119         '''now do the fitting'''
# --> 120         skw_res=skw.fit(self.shot,verbose=False, **iv_dict)
#     121         self.skw_res=skw_res
#     122         ##Calculating alpha. This is really ugly
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, **kwargs)
#     539                              scale_covar=scale_covar, fcn_kws=kwargs,
#     540                              **fit_kws)
# --> 541         output.fit(data=data, weights=weights)
#     542         output.components = self.components
#     543         return output
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in fit(self, data, params, weights, method, **kwargs)
#     743         self.userargs = (self.data, self.weights)
#     744         self.userkws.update(kwargs)
# --> 745         self.init_fit    = self.model.eval(params=self.params, **self.userkws)
#     746
#     747         _ret = self.minimize(method=self.method)
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     410     def eval(self, params=None, **kwargs):
#     411         """evaluate the model with the supplied parameters"""
# --> 412         return self.func(**self.make_funcargs(params, kwargs))
#     413
#     414     @property
#
# C:\Users\jdhare\Documents\GitHub\thomson_scattering\spectral_density_functions.py in Skw_nLTE_stray_light_convolve(lambda_range, lambda_in, response, theta, Z_Te_table, n_e, T_e, V_fe, A, T_i, V_fi, stry, amp, offset, shift)
#     360     skw=S_k_omega_nLTE(lambda_range, lambda_in, theta,  Z_Te_table, T_e, T_i, n_e, A,V_fi, V_fe)
#     361     skw_conv=convolve(response,skw)
# --> 362     response_sh=reponse#np.interp(lambda_range+shift, lambda_range, response)
#     363     skw_conv_stray=amp*skw_conv/skw_conv.max()+stry*response_sh/response_sh.max()+offset #add in some of the background to account for unshifted light
#     364     return skw_conv_stray
#
# NameError: name 'reponse' is not defined

# %%
import numpy as np
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return idx

l0_found=f.lamb[find_nearest(f.lamb,f.l0)]
print((l0_found-f.l0)*1e10)
# Out:
# -0.0174346221029

# %%
f.skw_res.eval()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-e6fcff2274d6> in <module>()
# ----> 1 f.skw_res.eval()
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     771         if params is None:
#     772            params = self.params
# --> 773         return self.model.eval(params=params, **self.userkws)
#     774
#     775     def eval_components(self, params=None, **kwargs):
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\lmfit\model.py in eval(self, params, **kwargs)
#     410     def eval(self, params=None, **kwargs):
#     411         """evaluate the model with the supplied parameters"""
# --> 412         return self.func(**self.make_funcargs(params, kwargs))
#     413
#     414     @property
#
# C:\Users\jdhare\Documents\GitHub\thomson_scattering\spectral_density_functions.py in Skw_nLTE_stray_light_convolve(lambda_range, lambda_in, response, theta, Z_Te_table, n_e, T_e, V_fe, A, T_i, V_fi, stry, amp, offset, shift)
#     358
#     359 def Skw_nLTE_stray_light_convolve(lambda_range, lambda_in, response, theta,  Z_Te_table, n_e, T_e, V_fe, A, T_i, V_fi, stry, amp, offset, shift):
# --> 360     skw=S_k_omega_nLTE(lambda_range, lambda_in, theta,  Z_Te_table, T_e, T_i, n_e, A,V_fi, V_fe)
#     361     skw_conv=convolve(response,skw)
#     362     #response_sh=np.interp(lambda_range+shift, lambda_range, response)
#
# C:\Users\jdhare\Anaconda3\lib\site-packages\numpy\lib\function_base.py in interp(x, xp, fp, left, right, period)
#    1672             return compiled_interp([x], xp, fp, left, right).item()
#    1673         else:
# -> 1674             return compiled_interp(x, xp, fp, left, right)
#    1675     else:
#    1676         if period == 0:
#
# ValueError: fp and xp are not of the same length.

# %%
ts.fig.savefig('Figures/s0611_15 fibre 8A largetext.pdf')

# %%
for i in range(1,15):
    ts.plot_data(Fnum=i, Fset='A')

# %%
for i in range(1,15):
    ts.plot_data(Fnum=i, Fset='B')
