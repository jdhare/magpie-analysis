# %%
# %matplotlib notebook
#from plasma_parameter_calculator import *
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
cd "~\Google Drive\MAGPIE\data\2015\s0513_15 RECONNECTION - Carbon repeat"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2015\s0513_15 RECONNECTION - Carbon repeat

# %%
eo=np.loadtxt(open('s0513_15 neL end on.txt',"r"),delimiter=",")
eo=np.nan_to_num(eo)
eo=eo-eo.min()

# %%
so=np.loadtxt(open('s0513_15 neL side on.txt',"r"),delimiter=",")
so=np.nan_to_num(so)
so=so-so.min()

# %%
fig, ax=plt.subplots()
ax.imshow(so[240:3030,2070:2900])
# Out:
# <img src="data:image/png;base64,...">

# %%
soc=so[240:3030,2070:2900]

# %%
fig, ax=plt.subplots()
ax.imshow(eo[620:2120,:])
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
eoc=eo[621:2120,:]#950:3850
eoc=eoc.transpose()

# %%
fig, ax=plt.subplots(1,2)
ax[0].imshow(eoc)
ax[1].imshow(soc)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
s_scale=101
e_scale=174
s_centre=2485-2070#414
e_centre=1408-621#799
s_mm_range=soc.shape[1]/(2*s_scale)
s_mm=np.linspace(-s_mm_range,s_mm_range, soc.shape[1])
e_mm_range=eoc.shape[1]/(2*e_scale)
e_mm=np.linspace(-e_mm_range,e_mm_range, eoc.shape[1])
i_eo=np.trapz(eoc,dx=0.1*(e_mm[1]-e_mm[0]),axis=0)
i_so=np.trapz(soc,dx=0.1*(s_mm[1]-s_mm[0]),axis=0)

# %%
eoc.min()
# Out:
# 0.0

# %%
fig, ax=plt.subplots()
ax.plot(s_mm,i_so, color='black')
ax.plot(e_mm,i_eo+2.4e17)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
i_eo_s=np.interp(s_mm,e_mm,i_eo)
fig, ax=plt.subplots()
ax.plot(s_mm,i_so-i_eo_s, color='black')
#ax.plot(s_mm,i_eo_s)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
so_bar=np.mean(soc, axis=0)
eo_bar=np.mean(eoc, axis=0)

# %%
fig, ax=plt.subplots()
ax.plot(np.trapz(soc,dx=0.1*(s_mm[1]-s_mm[0]),axis=1), color='black')
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
Az0=eoc[:, eoc.shape[1]/2]
Ax0=soc[:, soc.shape[1]/2]
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   if __name__ == '__main__':
# C:\Users\jdavies\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   from ipykernel import kernelapp as app

# %%
fig, ax=plt.subplots()
ax.plot(Az0, color='black')
ax.plot(Ax0)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\matplotlib\pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
