# %%
# %matplotlib notebook
from bdots import ScopeChannel, MitlBdots
import matplotlib.pyplot as plt
import numpy as np
import csv
from ipywidgets import interact

# %%
cd "~\Google Drive\MAGPIE\data\"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data

# %%
filename="Carbon Reconnection Shot Book.csv"
shots=[]

with open(filename, 'r') as f:
    reader = csv.reader(f, delimiter=',')
    next(reader)
    for row in reader:
        shots.append(row[0])
        
shots=['s0426_15' if s=='s0426_16' else s for s in shots]

# %%
ScopeChannel(shots[1], scope, channel)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\numpy\lib\npyio.py:891: UserWarning: loadtxt: Empty input file: "//LINNA/scopes/scope2_s0512B15time"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# C:\Users\jdavies\Anaconda3\lib\site-packages\numpy\lib\npyio.py:891: UserWarning: loadtxt: Empty input file: "//LINNA/scopes/scope2_s0512B15_A1"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)

# %% [markdown]
# # Ekspla Diode

# %%
scope="2"
channel='A1'

fig, ax=plt.subplots(figsize=(12,4), sharex=True)
    
i=40
s=shots[i]
Ek=ScopeChannel(s, "2", "A1")
Fa=ScopeChannel(s, "2", "A2")
R1=ScopeChannel(s, "2", "C1")
R2=ScopeChannel(s, "2", "C2")

ax.plot(Ek.time,Ek.data)
ax.plot(Fa.time,Fa.data)
ax.plot(R1.time,R1.data)
ax.plot(R1.time,R2.data)

ax.set_title(s)
ax.set_xlim([1440,2000])

#banks


fig2, ax2=plt.subplots(figsize=(12,4), sharex=True)
for lg in ["A1", "A2", "B1", "B2"]:
    c=ScopeChannel(s, "10", lg)
    ax2.plot(c.time,c.data)

ax2.set_title(s)
ax2.set_xlim([1000,3000])
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# (1000, 3000)

# %% [markdown]
# # Thomson

# %%
scope="2"
channel='A1'

fig, ax=plt.subplots(figsize=(12,4), sharex=True)
    
s='s0825_16'
TB=ScopeChannel(s, "2", "D1")

ax.plot(TB.time,TB.data)

ax.set_title(s)
ax.set_xlim([1440,2000])
# Out:
# <img src="data:image/png;base64,...">
# (1440, 2000)
