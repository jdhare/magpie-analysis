# %%
# %matplotlib notebook
from bdots import ScopeChannel
import matplotlib.pyplot as plt
# Out:
# c:\users\jdavies\anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
scope="11"
channel="C1"#chico

# %%
shots=['s1026_15', 's0121_16', 's0429_16']
shots=['s0429_16', 's0505_16', 's0511_16']

sc=[ScopeChannel(s, scope, channel) for s in shots]

# %%
fig, ax=plt.subplots(figsize=(12,8))
for s in sc:
    ax.plot(s.time, s.data, label=s.shot)
    
ax.set_xlim(0,3000)
ax.legend()
# Out:
# <img src="data:image/png;base64,...">
