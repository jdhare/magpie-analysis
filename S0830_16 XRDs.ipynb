# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0830_16 Reconnection C Faraday"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0830_16 Reconnection C Faraday

# %%
data=np.loadtxt('s0830_16 XRDs 2 3 and 4.csv', skiprows=15, delimiter=',')

# %%
t=data[:,0]
Be=data[:,2]
Al=data[:,3]
PCB=data[:,4]

# %%
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(t*1e9,Be)
#ax.plot(t*1e9,PCB)
#ax.plot(t*1e9,Al)


ax.set_xlim([1500,2000])
# Out:
# <img src="data:image/png;base64,...">
# (1500, 2000)
