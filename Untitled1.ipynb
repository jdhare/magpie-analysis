# %%
# %matplotlib notebook
from scipy.special import erfi
import numpy as np
import matplotlib.pyplot as plt

# %%
def B_Loureiro(x,d_sp):
    x0=0.92*d_sp
    if abs(x)<x0:
        return 1.85/2.0*np.sqrt(np.pi)*np.exp(-x**2/d_sp**2)*erfi(x/d_sp)
    if x>x0:
        return 1
    if x<-x0:
        return -1

# %%
Bv=np.vectorize(B_Loureiro)

# %%
x=np.linspace(-1,1, 1000)
d_sp=1
B=Bv(x,d_sp)
B1=np.tanh(x/d_sp)

# %%
fig, ax=plt.subplots()
ax.plot(x, 1.85/2.0*np.sqrt(np.pi)*np.exp(-x**2/d_sp**2)*erfi(x/d_sp))
ax.plot(x, np.tanh(x/0.5*d_sp))
# Out:
# <img src="data:image/png;base64,...">

# %%
1.85/2.0*np.sqrt(np.pi)*np.exp(-x**2/d_sp**2)*erfi(x/d_sp)
# Out:
# array([-0.55747972, -0.55900416, -0.5605351 , -0.56207253, -0.56361648,
#        -0.56516693, -0.56672389, -0.56828737, -0.56985737, -0.5714339 ,
#        -0.57301694, -0.57460651, -0.57620261, -0.57780523, -0.57941437,
#        -0.58103004, -0.58265222, -0.58428093, -0.58591614, -0.58755787,
#        -0.5892061 , -0.59086083, -0.59252205, -0.59418975, -0.59586393,
#        -0.59754459, -0.5992317 , -0.60092526, -0.60262526, -0.60433168,
#        -0.60604452, -0.60776376, -0.60948939, -0.61122139, -0.61295975,
#        -0.61470445, -0.61645547, -0.61821279, -0.6199764 , -0.62174627,
#        -0.62352238, -0.62530472, -0.62709326, -0.62888797, -0.63068883,
#        -0.63249581, -0.63430889, -0.63612804, -0.63795324, -0.63978444,
#        -0.64162162, -0.64346476, -0.64531381, -0.64716874, -0.64902952,
#        -0.65089611, -0.65276847, -0.65464657, -0.65653037, -0.65841982,
#        -0.66031489, -0.66221553, -0.6641217 , -0.66603336, -0.66795045,
# ...

# %%
        bk_im=plt.imread(bk_fn) #read background image
        bk_im=np.asarray(bk_im,dtype=float)

# %%
cd "C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0120_16 C RECONNECTION 12 FRAME\s0120_16"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2016\s0120_16 C RECONNECTION 12 FRAME\s0120_16

# %%
import numpy as np
import matplotlib.pyplot as plt

bk_im=plt.imread("s0120_16 Backgrounds.tif") #read background image
bk_im=np.asarray(bk_im,dtype=float)

# %%
bk_im.shape
# Out:
# (11688, 1082)

# %%
bks=[]
for i in range(12):
    bks.append(bk_im[i*974:(i+1)*974,:])

# %%
# %matplotlib inline
plt.imshow(bks[1])

# %%
import png

shot="s0120_16"
for i in range(0,12):
    if i<9:
        st="0"+str(i+1)
    else:
        st=str(i+1)
    bkfn=shot+" Background_0"+st+".png"
    f = open(bkfn, 'wb')
    b_im=np.clip(bks[i], a_min=0, a_max=2**16-1)
    pwriter = png.Writer(len(b_im[0]), len(b_im), greyscale=True, bitdepth=16)
    pwriter.write(f,b_im)
    f.close()

# %%
from svg.path import Path, parse_path

# %%
x="M318.835,2226.758c0,0,10.176,25.439,45.79,40.703s62.75,27.135,91.58,47.486c28.831,20.352,39.006,42.398,35.615,71.229c-3.392,28.831-16.959,69.533-5.088,111.931c11.872,42.398,32.223,88.188,54.27,127.195"

# %%
path1 = parse_path(x)

# %%
C=path1[4]

# %%
C.length()
# Out:
# 138.60469694224344

# %%
C.point(1.0)
# Out:
# (486.73199999999997+2498.1069999999995j)

# %%
a=(0,1)

# %%
a.*2
# Out:
#   File "<ipython-input-4-835db069f990>", line 1
#     a.*2
#       ^
# SyntaxError: invalid syntax

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import colormaps as cmaps
import os
import scipy as sp
from scipy.ndimage.interpolation import rotate
from magpie_data import NeLMap2, OpticalFrames, PolarimetryMap, FaradayMap
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
# %cd "~\Google Drive\MAGPIE\data\2015\s1006_15 Reconnection C TS upstream flow"
# Out:
# C:\Users\jdavies\Google Drive\MAGPIE\data\2015\s1006_15 Reconnection C TS upstream flow

# %%
s1006_15_532=NeLMap2('s1006_15 532nm neL.txt', scale=173, multiply_by=1/1.6, rot_angle=-90)
#s1006_15_532.set_origin(origin=(1760,2328), x_range=10, y_range=10)

# %%
s=s1006_15_532

# %%
s.plot_data_px(clim=[0,2], cmap=cmaps.cmaps['inferno'], multiply_by=1e-18)
# Out:
# <div id='338727fa-dd8f-4f45-a67d-afdba50ab32e'></div>

# %%
s1006_15_532.set_origin(origin=(2290,1411), x_range=8, y_range=11.5)
# Out:
# 300.5 4279.5 27 2795

# %%
s.plot_data_mm(clim=[0,2], cmap=cmaps.cmaps['inferno'], multiply_by=1e-18)
# Out:
# <img src="data:image/png;base64,...">

# %%
s.create_lineout(start=(5,0), end=(-5,0))

# %%
s.lo.max()
# Out:
# 0.0

# %%
s.plot_lineout()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.plot(profile_line(s.neL, (500,500),(1000,2000),linewidth=1))

# %%
s.create_lineout(start=(4,-10), end=(4,10))
s.plot_lineout()

# %%
cd "\\linna\Users\Magpie\Documents\MAGPIE data\2016\June_2016\s0623_16 Gas Liner Steel Spec Bdot\s0623_16 op spec\shot
# Out:
# \\linna\Users\Magpie\Documents\MAGPIE data\2016\June_2016\s0623_16 Gas Liner Steel Spec Bdot\s0623_16 op spec\shot

# %%
d=np.genfromtxt('s0623_16 shot spectroscopy.asc')

# %%
fig, ax=plt.subplots(figsize=(12,8))
ax.imshow(d.T)
# Out:
# <img src="data:image/png;base64,...">

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import colormaps as cmaps
from scipy.ndimage.interpolation import rotate
from scipy.ndimage import zoom
import os
import image_registration as ir
from skimage.measure import profile_line
import imreg_dft as ird

# %%
# %matplotlib inline

# %%
cd "D:\s0701_16 Far\Reg tests"
# Out:
# D:\s0701_16 Far\Reg tests

# %%
R0fn='s0630_16_102533_c1.png'
R1fn='s0630_16_102526_c2.png'

# %%
R0=plt.imread(R0fn)
R1=np.fliplr(plt.imread(R1fn))
R0s=R0.sum()
R1s=R1.sum()
R0=R0*R1s/R0s
result=ird.similarity(R0, R1, numiter=3)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py:549: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)

# %%
result
# Out:
# {'Dangle': 0.013416815742397137,
#  'Dscale': 0.00053876011867480013,
#  'Dt': 0.25,
#  'angle': 1.1308339702711976,
#  'scale': 0.99757762821321472,
#  'success': 0.11428169142015529,
#  'timg': array([[ 0.00603615,  0.00602555,  0.00606558, ...,  0.00605337,
#           0.00605145,  0.00604778],
#         [ 0.00604788,  0.00605105,  0.00606307, ...,  0.00604905,
#           0.00604888,  0.00604838],
#         [ 0.00604506,  0.00604777,  0.00605187, ...,  0.00604331,
#           0.00604338,  0.00604384],
#         ...,
#         [ 0.00597066,  0.00567786,  0.00595602, ...,  0.00606616,
#           0.0060619 ,  0.00604417],
#         [ 0.00558233,  0.00576299,  0.00617599, ...,  0.00606044,
#           0.00605153,  0.0060089 ],
#         [ 0.00601867,  0.00569063,  0.00608249, ...,  0.00605667,
#           0.00605099,  0.00603318]], dtype=float32),
#  'tvec': array([ -22.01784342, -255.85632965])}

# %%
ird.imshow(R0,R1, result['timg'])

# %%
I0fn='IMG_3301.JPG'

# %%
I0=plt.imread(I0fn)
I0s=np.sum(I0,2)
scale=R0.shape[0]/I0s.shape[0]

I0z=zoom(I0s, scale)
crop=(I0z.shape[1]-R0.shape[1])/2
I0zc=I0z[:,crop:-crop]
I0zcn=np.flipud(I0zc/I0zc.max())

res_IF=ird.similarity(R0, I0zcn, numiter=3)
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py:549: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# C:\Users\jdavies\Anaconda3\lib\site-packages\ipykernel\__main__.py:7: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
ird.imshow(R0,I0zcn, res_IF['timg'])

# %%
scale
# Out:
# 0.7982954545454546

# %%
'reconnection '*48
# Out:
# 'reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection reconnection '

# %%
R1=47
R2=220
R1*R2/(R1+R2)
# Out:
# 38.72659176029963

# %%
RL=50
RP=10
RS=38.72

1/(RL*RP/(RS*(RL+RP+RS)+RP*(RS+RL)))
# Out:
# 9.419276799999999
