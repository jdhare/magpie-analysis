# %%
# %matplotlib nbagg
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
from bdots import *

# %%
fig, ax=plt.subplots(figsize=(12,8))
r=Rogowskis("s1214_15")
r.truncate(threshold=1.0,cal=[105*3e9,-103*3e9])
r.integrate(return_posts=8)
r.plot("I_Tot", scale=1e-6, ax=ax)


r=Rogowskis("s0115_16")
r.truncate(threshold=1.0,cal=[105*3e9,-103*3e9])
r.integrate(return_posts=8)
r.plot("I_Tot", scale=1e-6, ax=ax)
# Out:
# <img src="data:image/png;base64,...">
# s1214_15: using both Rogs
# s0115_16: using both Rogs

# %%
fig, ax=plt.subplots(figsize=(12,8))
ax.plot(r2.time,r2.bd2_tr-r2.bd1_tr)
# Out:
# <img src="data:image/png;base64,...">

# %%
r2.I1.max()*4
# Out:
# 1101090.5011199999

# %%
r.I2.max()<5e5
# Out:
# True
