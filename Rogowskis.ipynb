# %%
# %matplotlib nbagg
# Out:
# C:\Users\jdavies\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
from bdots import *

# %%
fig, ax=plt.subplots(figsize=(12,8))
r=Rogowskis("s0121_16")
r.truncate(cal=[10*10.4*3e9,-10.48*10.79*3e9])
r.integrate()
r.plot("I_Tot0", scale=1e-6, ax=ax)

r=Rogowskis("s1026_15")
r.truncate(cal=[10*10.4*3e9,-10.48*10.79*3e9])
r.integrate()
r.plot("I_Tot0", scale=1e-6, ax=ax)
# Out:
# <img src="data:image/png;base64,...">
# s0121_16: using both Rogs
# s1026_15: using both Rogs

# %%
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-52ca7a840402> in <module>()
# ----> 1 plt.close(gfg)
#
# NameError: name 'gfg' is not defined

# %%
0.002*1e6
# Out:
# 2000.0

# %%
r.I2.max()<5e5
# Out:
# True
