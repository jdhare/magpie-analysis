# %%
# %matplotlib inline

# %%
from bdots import *

# %%
r=Rogowskis("s0129_16")
r.truncate(cal=[10*10.4*3e9,-10.48*10.79*3e9], window=2000, threshold=0.2, start_offset=500)
r.integrate()
r.plot("I", scale=1e-6)
# Out:
# s0129_16: using Rog 1 only

# %%
np.mean(r.bd1_z[:1000])
# Out:
# 6.4392935428259083e-18

# %%
r.bd1_tr.shape
# Out:
# (1000,)

# %%
r.I2.max()<5e5
# Out:
# True
